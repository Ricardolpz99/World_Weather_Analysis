# %%
# Import dependencies

import random
from datetime import datetime
from citipy import citipy 
import time

import pandas as pd
import gmaps
import requests
import numpy as np


# Import Weather API key
from config import weather_api_key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates

# %%
# Create a list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Get the nearest city using the citipy module.

# First a list for cities 
cities = []
 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %%
# Perform an API call with the OpenWeatherMap. (Metric used)

url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
#Retrieve the following information from the API call:
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)

import time  

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    time.sleep(1)    
        
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp(C)": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Date": city_date})       
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | palmer
# Processing Record 2 of Set 1 | rio grande
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bilma
# Processing Record 5 of Set 1 | waipawa
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | mayahi
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | bandarbeyla
# Processing Record 10 of Set 1 | guerrero negro
# Processing Record 11 of Set 1 | beckley
# Processing Record 12 of Set 1 | nerchinskiy zavod
# Processing Record 13 of Set 1 | middelburg
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | saint-augustin
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | vila
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | marawi
# Processing Record 23 of Set 1 | adiake
# Processing Record 24 of Set 1 | shanghai
# Processing Record 25 of Set 1 | katangli
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | kyshtovka
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | kamenka
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | kargil
# Processing Record 33 of Set 1 | jiayuguan
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | aldan
# Processing Record 36 of Set 1 | westport
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | vao
# Processing Record 40 of Set 1 | barra
# Processing Record 41 of Set 1 | bytow
# Processing Record 42 of Set 1 | aksu
# Processing Record 43 of Set 1 | comodoro rivadavia
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | kerema
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 1 | la rioja
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | aasiaat
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | huarmey
# Processing Record 6 of Set 2 | ovsyanka
# Processing Record 7 of Set 2 | kachug
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | luderitz
# Processing Record 10 of Set 2 | salalah
# Processing Record 11 of Set 2 | komsomolskiy
# Processing Record 12 of Set 2 | ermelo
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | baisha
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | rawson
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | opuwo
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | sibu
# Processing Record 28 of Set 2 | nuuk
# Processing Record 29 of Set 2 | chapais
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | shetpe
# Processing Record 32 of Set 2 | mayo
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | maumere
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | governador valadares
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | jinchang
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 2 | vidyayevo
# Processing Record 49 of Set 2 | edd
# Processing Record 50 of Set 2 | concarneau
# Processing Record 1 of Set 3 | akonolinga
# Processing Record 2 of Set 3 | quelimane
# Processing Record 3 of Set 3 | zenzeli
# Processing Record 4 of Set 3 | papara
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | atambua
# Processing Record 8 of Set 3 | marang
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | taonan
# Processing Record 11 of Set 3 | dire
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | bethanien
# Processing Record 14 of Set 3 | stromness
# Processing Record 15 of Set 3 | izumo
# Processing Record 16 of Set 3 | aykhal
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | dunedin
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | springhill
# Processing Record 23 of Set 3 | durban
# Processing Record 24 of Set 3 | cianorte
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | san patricio
# Processing Record 28 of Set 3 | kanker
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | joshimath
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | peru
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | inhambane
# Processing Record 38 of Set 3 | ahuimanu
# Processing Record 39 of Set 3 | porangatu
# Processing Record 40 of Set 3 | guaiba
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | tanabe
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | lorengau
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | egvekinot
# Processing Record 49 of Set 3 | namatanai
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 1 of Set 4 | bay city
# Processing Record 2 of Set 4 | vardo
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | sungaipenuh
# Processing Record 6 of Set 4 | grindavik
# Processing Record 7 of Set 4 | salmas
# Processing Record 8 of Set 4 | chernoyerkovskaya
# Processing Record 9 of Set 4 | moerai
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | lashio
# Processing Record 12 of Set 4 | north bend
# Processing Record 13 of Set 4 | yeppoon
# Processing Record 14 of Set 4 | muravlenko
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | kasane
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | caraquet
# Processing Record 21 of Set 4 | kenai
# Processing Record 22 of Set 4 | caala
# Processing Record 23 of Set 4 | itarema
# Processing Record 24 of Set 4 | maubeuge
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | umm lajj
# Processing Record 27 of Set 4 | dubbo
# Processing Record 28 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 4 | los llanos de aridane
# Processing Record 30 of Set 4 | waingapu
# Processing Record 31 of Set 4 | alta floresta
# Processing Record 32 of Set 4 | half moon bay
# Processing Record 33 of Set 4 | fort nelson
# Processing Record 34 of Set 4 | sangar
# Processing Record 35 of Set 4 | clarence town
# Processing Record 36 of Set 4 | dieppe
# Processing Record 37 of Set 4 | gamba
# Processing Record 38 of Set 4 | ayagoz
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | pangnirtung
# Processing Record 41 of Set 4 | lima
# Processing Record 42 of Set 4 | xining
# Processing Record 43 of Set 4 | rodez
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | oranjemund
# Processing Record 48 of Set 4 | ryotsu
# Processing Record 49 of Set 4 | eureka
# Processing Record 50 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 5 | poykovskiy
# Processing Record 2 of Set 5 | sao miguel do araguaia
# Processing Record 3 of Set 5 | ystad
# Processing Record 4 of Set 5 | prainha
# Processing Record 5 of Set 5 | kautokeino
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | karlshamn
# Processing Record 8 of Set 5 | mabaruma
# Processing Record 9 of Set 5 | tura
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | cuamba
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | riyadh
# Processing Record 14 of Set 5 | santa rosa
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | san cristobal
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | beringovskiy
# Processing Record 21 of Set 5 | general higinio morinigo
# Processing Record 22 of Set 5 | honiara
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | kualakapuas
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | constitucion
# Processing Record 27 of Set 5 | ginda
# Processing Record 28 of Set 5 | nakatsu
# Processing Record 29 of Set 5 | general roca
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | susanville
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 5 | puerto leguizamo
# Processing Record 37 of Set 5 | henties bay
# Processing Record 38 of Set 5 | brzeg
# Processing Record 39 of Set 5 | yining
# Processing Record 40 of Set 5 | olafsvik
# Processing Record 41 of Set 5 | ashland
# Processing Record 42 of Set 5 | taltal
# Processing Record 43 of Set 5 | talaya
# Processing Record 44 of Set 5 | keti bandar
# Processing Record 45 of Set 5 | tarnogskiy gorodok
# Processing Record 46 of Set 5 | naica
# Processing Record 47 of Set 5 | valparaiso
# Processing Record 48 of Set 5 | guiratinga
# Processing Record 49 of Set 5 | sistranda
# Processing Record 50 of Set 5 | nioro
# Processing Record 1 of Set 6 | shieli
# Processing Record 2 of Set 6 | jalingo
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | redlands
# Processing Record 5 of Set 6 | cayenne
# Processing Record 6 of Set 6 | chiredzi
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | olga
# Processing Record 10 of Set 6 | mattru
# Processing Record 11 of Set 6 | esperance
# Processing Record 12 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 6 | roebourne
# Processing Record 14 of Set 6 | rognan
# Processing Record 15 of Set 6 | mocuba
# Processing Record 16 of Set 6 | myitkyina
# Processing Record 17 of Set 6 | mancio lima
# Processing Record 18 of Set 6 | rudbar
# Processing Record 19 of Set 6 | gizo
# Processing Record 20 of Set 6 | icod de los vinos
# Processing Record 21 of Set 6 | tocopilla
# Processing Record 22 of Set 6 | coos bay
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | mwense
# Processing Record 25 of Set 6 | ulaangom
# Processing Record 26 of Set 6 | samdrup jongkhar
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | murmashi
# Processing Record 29 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | socorro
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | glendive
# Processing Record 33 of Set 6 | hobyo
# Processing Record 34 of Set 6 | challapata
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | barahona
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | rio gallegos
# Processing Record 39 of Set 6 | merauke
# Processing Record 40 of Set 6 | abilene
# Processing Record 41 of Set 6 | chegdomyn
# Processing Record 42 of Set 6 | southbridge
# Processing Record 43 of Set 6 | hambantota
# Processing Record 44 of Set 6 | nikolskoye
# Processing Record 45 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | kuryk
# Processing Record 48 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 6 | agadir
# Processing Record 50 of Set 6 | orlik
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | coquimbo
# Processing Record 3 of Set 7 | pathein
# Processing Record 4 of Set 7 | qaqortoq
# Processing Record 5 of Set 7 | adre
# Processing Record 6 of Set 7 | kennett
# Processing Record 7 of Set 7 | erenhot
# Processing Record 8 of Set 7 | colares
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | mogadishu
# Processing Record 11 of Set 7 | mandalgovi
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | hervey bay
# Processing Record 14 of Set 7 | atasu
# Processing Record 15 of Set 7 | hvolsvollur
# Processing Record 16 of Set 7 | mokhsogollokh
# Processing Record 17 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 7 | tambopata
# Processing Record 19 of Set 7 | shelburne
# Processing Record 20 of Set 7 | bambous virieux
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | kayfan
# City not found. Skipping...
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | asheboro
# Processing Record 25 of Set 7 | miri
# Processing Record 26 of Set 7 | gazli
# Processing Record 27 of Set 7 | ponta delgada
# Processing Record 28 of Set 7 | helong
# Processing Record 29 of Set 7 | kalaleh
# Processing Record 30 of Set 7 | nelson bay
# Processing Record 31 of Set 7 | arlit
# Processing Record 32 of Set 7 | kloulklubed
# Processing Record 33 of Set 7 | tabuk
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | itapui
# Processing Record 36 of Set 7 | leningradskiy
# Processing Record 37 of Set 7 | lagos
# Processing Record 38 of Set 7 | fuxin
# Processing Record 39 of Set 7 | srednekolymsk
# Processing Record 40 of Set 7 | kangaatsiaq
# Processing Record 41 of Set 7 | qafsah
# City not found. Skipping...
# Processing Record 42 of Set 7 | canchungo
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | varnavino
# Processing Record 45 of Set 7 | zhigansk
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | padang
# Processing Record 48 of Set 7 | jacqueville
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | araouane
# Processing Record 1 of Set 8 | hovd
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | tumut
# Processing Record 4 of Set 8 | saskylakh
# Processing Record 5 of Set 8 | nagato
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | pumiao
# Processing Record 8 of Set 8 | gallipoli
# Processing Record 9 of Set 8 | santa rita arriba
# Processing Record 10 of Set 8 | tecoanapa
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | sutton
# Processing Record 13 of Set 8 | dzhebariki-khaya
# Processing Record 14 of Set 8 | acapulco
# Processing Record 15 of Set 8 | hay river
# Processing Record 16 of Set 8 | samarai
# Processing Record 17 of Set 8 | monte santo de minas
# Processing Record 18 of Set 8 | seoul
# Processing Record 19 of Set 8 | amalapuram
# Processing Record 20 of Set 8 | puri
# Processing Record 21 of Set 8 | brae
# Processing Record 22 of Set 8 | rio blanco
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | mahibadhoo
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | coari
# Processing Record 28 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 29 of Set 8 | tommot
# Processing Record 30 of Set 8 | tutoia
# Processing Record 31 of Set 8 | sandwick
# Processing Record 32 of Set 8 | catuday
# Processing Record 33 of Set 8 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | guipavas
# Processing Record 35 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 8 | manado
# Processing Record 37 of Set 8 | atikokan
# Processing Record 38 of Set 8 | nabire
# Processing Record 39 of Set 8 | sola
# Processing Record 40 of Set 8 | redcar
# Processing Record 41 of Set 8 | paamiut
# Processing Record 42 of Set 8 | cidreira
# Processing Record 43 of Set 8 | diffa
# Processing Record 44 of Set 8 | saint albans
# Processing Record 45 of Set 8 | murfreesboro
# Processing Record 46 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 47 of Set 8 | west wendover
# Processing Record 48 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 8 | bubaque
# Processing Record 50 of Set 8 | cay
# Processing Record 1 of Set 9 | yuzhou
# Processing Record 2 of Set 9 | high level
# Processing Record 3 of Set 9 | kanniyakumari
# Processing Record 4 of Set 9 | basar
# Processing Record 5 of Set 9 | kiama
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | alugan
# Processing Record 8 of Set 9 | sept-iles
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | adrar
# Processing Record 11 of Set 9 | alghero
# Processing Record 12 of Set 9 | longyearbyen
# Processing Record 13 of Set 9 | katherine
# Processing Record 14 of Set 9 | catumbela
# Processing Record 15 of Set 9 | altay
# Processing Record 16 of Set 9 | dzerzhinsk
# Processing Record 17 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 9 | surt
# Processing Record 19 of Set 9 | krasnogorsk
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | bauchi
# Processing Record 22 of Set 9 | bourail
# Processing Record 23 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 9 | leshukonskoye
# Processing Record 25 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 9 | mercedes
# Processing Record 27 of Set 9 | luangwa
# Processing Record 28 of Set 9 | fukue
# Processing Record 29 of Set 9 | thompson
# Processing Record 30 of Set 9 | chiang khong
# Processing Record 31 of Set 9 | vila franca do campo
# Processing Record 32 of Set 9 | chauk
# Processing Record 33 of Set 9 | swampscott
# Processing Record 34 of Set 9 | beyneu
# Processing Record 35 of Set 9 | tete
# Processing Record 36 of Set 9 | okhotsk
# Processing Record 37 of Set 9 | axim
# Processing Record 38 of Set 9 | pahrump
# Processing Record 39 of Set 9 | puerto escondido
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | salinopolis
# Processing Record 42 of Set 9 | tamiahua
# Processing Record 43 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 9 | abu zabad
# Processing Record 45 of Set 9 | blagoyevo
# Processing Record 46 of Set 9 | totma
# Processing Record 47 of Set 9 | havoysund
# Processing Record 48 of Set 9 | mwinilunga
# Processing Record 49 of Set 9 | altus
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | clearwater
# Processing Record 2 of Set 10 | mokrousovo
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | benjamin aceval
# Processing Record 5 of Set 10 | dangara
# Processing Record 6 of Set 10 | sharlyk
# Processing Record 7 of Set 10 | launceston
# Processing Record 8 of Set 10 | nizwa
# Processing Record 9 of Set 10 | yantal
# Processing Record 10 of Set 10 | calvinia
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | turukhansk
# Processing Record 13 of Set 10 | hashtrud
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | leua
# Processing Record 16 of Set 10 | rurrenabaque
# Processing Record 17 of Set 10 | malakal
# Processing Record 18 of Set 10 | muros
# Processing Record 19 of Set 10 | mecca
# Processing Record 20 of Set 10 | banda aceh
# Processing Record 21 of Set 10 | belmonte
# Processing Record 22 of Set 10 | mackay
# Processing Record 23 of Set 10 | baracoa
# Processing Record 24 of Set 10 | nishihara
# Processing Record 25 of Set 10 | ilulissat
# Processing Record 26 of Set 10 | amarante
# Processing Record 27 of Set 10 | pala
# Processing Record 28 of Set 10 | laizhou
# Processing Record 29 of Set 10 | bonavista
# Processing Record 30 of Set 10 | anadyr
# Processing Record 31 of Set 10 | viedma
# Processing Record 32 of Set 10 | santo antonio do leverger
# Processing Record 33 of Set 10 | tomatlan
# Processing Record 34 of Set 10 | puerto del rosario
# Processing Record 35 of Set 10 | kaniama
# Processing Record 36 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 37 of Set 10 | victoria
# Processing Record 38 of Set 10 | husavik
# Processing Record 39 of Set 10 | poum
# Processing Record 40 of Set 10 | ugoofaaru
# Processing Record 41 of Set 10 | kargasok
# Processing Record 42 of Set 10 | freistadt
# Processing Record 43 of Set 10 | gimli
# Processing Record 44 of Set 10 | tiznit
# Processing Record 45 of Set 10 | kununurra
# Processing Record 46 of Set 10 | olinda
# Processing Record 47 of Set 10 | batemans bay
# Processing Record 48 of Set 10 | sharjah
# Processing Record 49 of Set 10 | vila velha
# Processing Record 50 of Set 10 | auki
# Processing Record 1 of Set 11 | chumikan
# Processing Record 2 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 11 | porto novo
# Processing Record 4 of Set 11 | seabra
# Processing Record 5 of Set 11 | alyangula
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 11 | garavuti
# Processing Record 9 of Set 11 | jalu
# Processing Record 10 of Set 11 | kembe
# Processing Record 11 of Set 11 | skvyra
# Processing Record 12 of Set 11 | shubarshi
# Processing Record 13 of Set 11 | bayshore gardens
# Processing Record 14 of Set 11 | sakakah
# Processing Record 15 of Set 11 | izhma
# Processing Record 16 of Set 11 | nueva loja
# Processing Record 17 of Set 11 | kasese
# Processing Record 18 of Set 11 | sorong
# Processing Record 19 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 20 of Set 11 | tanout
# Processing Record 21 of Set 11 | praia
# Processing Record 22 of Set 11 | teluk nibung
# Processing Record 23 of Set 11 | kahului
# Processing Record 24 of Set 11 | ranfurly
# Processing Record 25 of Set 11 | amahai
# Processing Record 26 of Set 11 | san policarpo
# Processing Record 27 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 11 | kaka
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | flinders
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | apricena
# Processing Record 33 of Set 11 | lata
# Processing Record 34 of Set 11 | siderno
# Processing Record 35 of Set 11 | abu kamal
# Processing Record 36 of Set 11 | miraflores
# Processing Record 37 of Set 11 | la celle-saint-cloud
# Processing Record 38 of Set 11 | rochefort
# Processing Record 39 of Set 11 | odweyne
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | yar-sale
# Processing Record 42 of Set 11 | sai buri
# Processing Record 43 of Set 11 | tuatapere
# Processing Record 44 of Set 11 | boguchany
# Processing Record 45 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 11 | jacareacanga
# Processing Record 47 of Set 11 | gat
# Processing Record 48 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 11 | tongren
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | mount pleasant
# Processing Record 2 of Set 12 | songjianghe
# Processing Record 3 of Set 12 | ouargaye
# Processing Record 4 of Set 12 | shenjiamen
# Processing Record 5 of Set 12 | boundiali
# Processing Record 6 of Set 12 | lyubashivka
# Processing Record 7 of Set 12 | port blair
# Processing Record 8 of Set 12 | bekkevoort
# Processing Record 9 of Set 12 | karlstad
# Processing Record 10 of Set 12 | san jorge
# Processing Record 11 of Set 12 | hamilton
# Processing Record 12 of Set 12 | tahta
# Processing Record 13 of Set 12 | tarbert
# Processing Record 14 of Set 12 | mitzic
# Processing Record 15 of Set 12 | manzanillo
# Processing Record 16 of Set 12 | bambanglipuro
# Processing Record 17 of Set 12 | grand island
# Processing Record 18 of Set 12 | krizevci
# Processing Record 19 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 12 | batagay
# Processing Record 21 of Set 12 | alberton
# Processing Record 22 of Set 12 | tynda
# Processing Record 23 of Set 12 | bereda
# Processing Record 24 of Set 12 | kendari
# Processing Record 25 of Set 12 | richards bay
# Processing Record 26 of Set 12 | amursk
# Processing Record 27 of Set 12 | borova
# Processing Record 28 of Set 12 | tocache
# Processing Record 29 of Set 12 | verkh-chebula
# Processing Record 30 of Set 12 | darhan
# Processing Record 31 of Set 12 | zaozerne
# Processing Record 32 of Set 12 | gornopravdinsk
# Processing Record 33 of Set 12 | kalutara
# Processing Record 34 of Set 12 | sawakin
# Processing Record 35 of Set 12 | santa teresa
# Processing Record 36 of Set 12 | aklavik
# Processing Record 37 of Set 12 | kawalu
# Processing Record 38 of Set 12 | sorland
# Processing Record 39 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 12 | north vanlaiphai
# Processing Record 41 of Set 12 | san jeronimo
# Processing Record 42 of Set 12 | atbasar
# Processing Record 43 of Set 12 | hasaki
# Processing Record 44 of Set 12 | poronaysk
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | dingle
# Processing Record 47 of Set 12 | dalbandin
# Processing Record 48 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 12 | krasnoselkup
# Processing Record 50 of Set 12 | daru
# Processing Record 1 of Set 13 | tautira
# Processing Record 2 of Set 13 | uinskoye
# Processing Record 3 of Set 13 | vallenar
# Processing Record 4 of Set 13 | walvis bay
# Processing Record 5 of Set 13 | kolosovka
# Processing Record 6 of Set 13 | tahe
# Processing Record 7 of Set 13 | ola
# Processing Record 8 of Set 13 | boditi
# Processing Record 9 of Set 13 | novopavlovka
# Processing Record 10 of Set 13 | huilong
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | arman
# Processing Record 13 of Set 13 | oranjestad
# Processing Record 14 of Set 13 | portland
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | kibuye
# Processing Record 17 of Set 13 | asyut
# Processing Record 18 of Set 13 | kapit
# Processing Record 19 of Set 13 | burnie
# Processing Record 20 of Set 13 | azangaro
# Processing Record 21 of Set 13 | mpulungu
# Processing Record 22 of Set 13 | ibirite
# Processing Record 23 of Set 13 | rantepao
# Processing Record 24 of Set 13 | menongue
# Processing Record 25 of Set 13 | khvorostyanka
# Processing Record 26 of Set 13 | cabedelo
# Processing Record 27 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 13 | northam
# Processing Record 29 of Set 13 | balsas
# Processing Record 30 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 13 | howard springs
# Processing Record 32 of Set 13 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 33 of Set 13 | port moresby
# Processing Record 34 of Set 13 | tchollire
# Processing Record 35 of Set 13 | bay roberts
# Processing Record 36 of Set 13 | tevaitoa
# Processing Record 37 of Set 13 | maryville
# Processing Record 38 of Set 13 | safranbolu
# Processing Record 39 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 13 | manggar
# Processing Record 41 of Set 13 | batetskiy
# Processing Record 42 of Set 13 | korgen
# Processing Record 43 of Set 13 | noumea
# Processing Record 44 of Set 13 | coahuayana
# Processing Record 45 of Set 13 | jorochito
# Processing Record 46 of Set 13 | bintulu
# Processing Record 47 of Set 13 | manokwari
# Processing Record 48 of Set 13 | santander
# Processing Record 49 of Set 13 | lagoa
# Processing Record 50 of Set 13 | ostrovnoy
# Processing Record 1 of Set 14 | verkhnyaya inta
# Processing Record 2 of Set 14 | inongo
# Processing Record 3 of Set 14 | atar
# Processing Record 4 of Set 14 | salinas
# Processing Record 5 of Set 14 | northport
# Processing Record 6 of Set 14 | kopong
# Processing Record 7 of Set 14 | ushtobe
# Processing Record 8 of Set 14 | barreirinha
# Processing Record 9 of Set 14 | maragogi
# Processing Record 10 of Set 14 | nanortalik
# Processing Record 11 of Set 14 | porohy
# Processing Record 12 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 14 | naenwa
# City not found. Skipping...
# Processing Record 15 of Set 14 | peniche
# Processing Record 16 of Set 14 | neuquen
# Processing Record 17 of Set 14 | xalpatlahuac
# Processing Record 18 of Set 14 | kichera
# Processing Record 19 of Set 14 | santo augusto
# Processing Record 20 of Set 14 | ramgarh
# Processing Record 21 of Set 14 | ibra
# Processing Record 22 of Set 14 | muyezerskiy
# Processing Record 23 of Set 14 | sawai madhopur
# Processing Record 24 of Set 14 | charters towers
# Processing Record 25 of Set 14 | khudumelapye
# Processing Record 26 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 14 | xiongyue
# Processing Record 28 of Set 14 | tornio
# Processing Record 29 of Set 14 | qasigiannguit
# Processing Record 30 of Set 14 | santa ines
# Processing Record 31 of Set 14 | novobiryusinskiy
# Processing Record 32 of Set 14 | ajdabiya
# Processing Record 33 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 14 | angra
# City not found. Skipping...
# Processing Record 35 of Set 14 | berdigestyakh
# Processing Record 36 of Set 14 | port huron
# Processing Record 37 of Set 14 | hargeysa
# Processing Record 38 of Set 14 | daugai
# Processing Record 39 of Set 14 | asbestovskiy
# Processing Record 40 of Set 14 | hermosillo
# Processing Record 41 of Set 14 | hastings
# Processing Record 42 of Set 14 | nepalganj
# City not found. Skipping...
# Processing Record 43 of Set 14 | catamarca
# Processing Record 44 of Set 14 | talavera de la reina
# Processing Record 45 of Set 14 | enshi
# Processing Record 46 of Set 14 | yenagoa
# Processing Record 47 of Set 14 | verkhnevilyuysk
# Processing Record 48 of Set 14 | buritis
# Processing Record 49 of Set 14 | dalvik
# Processing Record 50 of Set 14 | mianwali
# Processing Record 1 of Set 15 | san rafael
# Processing Record 2 of Set 15 | ena
# Processing Record 3 of Set 15 | wuda
# Processing Record 4 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 15 | dwarka
# Processing Record 6 of Set 15 | campbellsville
# Processing Record 7 of Set 15 | karwar
# Processing Record 8 of Set 15 | zhuanghe
# Processing Record 9 of Set 15 | sambava
# Processing Record 10 of Set 15 | normandin
# Processing Record 11 of Set 15 | santa vitoria do palmar
# Processing Record 12 of Set 15 | harper
# Processing Record 13 of Set 15 | kasempa
# Processing Record 14 of Set 15 | vestmannaeyjar
# Processing Record 15 of Set 15 | eyl
# Processing Record 16 of Set 15 | soyo
# Processing Record 17 of Set 15 | suntar
# Processing Record 18 of Set 15 | at-bashi
# Processing Record 19 of Set 15 | ville-marie
# Processing Record 20 of Set 15 | ust-nera
# Processing Record 21 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 22 of Set 15 | najran
# Processing Record 23 of Set 15 | winneba
# Processing Record 24 of Set 15 | boulsa
# Processing Record 25 of Set 15 | progreso
# Processing Record 26 of Set 15 | saiha
# Processing Record 27 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 15 | andenes
# Processing Record 29 of Set 15 | gulbene
# Processing Record 30 of Set 15 | visakhapatnam
# Processing Record 31 of Set 15 | limbang
# Processing Record 32 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 15 | tateyama
# Processing Record 34 of Set 15 | kinsale
# Processing Record 35 of Set 15 | woodward
# Processing Record 36 of Set 15 | kyra
# Processing Record 37 of Set 15 | iset
# Processing Record 38 of Set 15 | el sauce
# Processing Record 39 of Set 15 | aksarka
# Processing Record 40 of Set 15 | turbaco
# Processing Record 41 of Set 15 | kruisfontein
# Processing Record 42 of Set 15 | morant bay
# Processing Record 43 of Set 15 | bandiagara
# Processing Record 44 of Set 15 | bodaybo
# Processing Record 45 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 46 of Set 15 | sosnovo-ozerskoye
# Processing Record 47 of Set 15 | sosnogorsk
# Processing Record 48 of Set 15 | yerbogachen
# Processing Record 49 of Set 15 | gao
# Processing Record 50 of Set 15 | kara-tyube
# Processing Record 1 of Set 16 | lebyazhye
# Processing Record 2 of Set 16 | oga
# Processing Record 3 of Set 16 | korla
# Processing Record 4 of Set 16 | cooma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp(C)  Humidity  \
# 0          Palmer      US  42.1584  -72.3287        -0.77        72
# 1      Rio Grande      BR -32.0350  -52.0986        17.75        93
# 2           Kapaa      US  22.0752 -159.3190        22.18        78
# 3           Bilma      NE  18.6853   12.9164        23.92        10
# 4         Waipawa      NZ -41.4122  175.5153        12.35        86
# 5         Ushuaia      AR -54.8000  -68.3000         8.81        61
# 6          Mayahi      NE  13.9553    7.6712        26.41         9
# 7     Bandarbeyla      SO   9.4942   50.8122        26.41        62
# 8  Guerrero Negro      MX  27.9769 -114.0611        17.18        59
# 9         Beckley      US  37.7782  -81.1882        -0.98        95
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0         100        1.54     overcast clouds  2022-02-13 09:59:33
# 1          99        6.07     overcast clouds  2022-02-13 09:59:35
# 2          75        5.66       broken clouds  2022-02-13 09:59:36
# 3           0        4.80           clear sky  2022-02-13 09:59:37
# 4         100        4.62     overcast clouds  2022-02-13 09:59:39
# 5          75        4.63       broken clouds  2022-02-13 09:57:13
# 6           0        6.72           clear sky  2022-02-13 09:59:41
# 7          66        7.45       broken clouds  2022-02-13 09:59:44
# 8         100        1.50     overcast clouds  2022-02-13 09:59:45
# 9         100        2.57          light snow  2022-02-13 09:55:24

# %%
# Create CSV file frothe DataFrame and saving it in the Weather_Database folder
weather_csv_file = "WeatherPy_Database.csv"
 
# Exporting data to the CSV file 
weather_data_df.to_csv(weather_csv_file, index_label="City_ID")
